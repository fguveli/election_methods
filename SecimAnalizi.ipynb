# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data.xlsx")

# %%
df = df.drop(columns='Sıra No')

# %%
df = df.drop(index=85)

# %%
df
# Out:
#                 il  Kayıtlı Seçmen Sayısı  Oy Kullanan Seçmen Sayısı  \
# 0            ADANA              1484820.0                  1271890.0
# 1         ADIYAMAN               381687.0                   325021.0
# 2   AFYONKARAHİSAR               495461.0                   440880.0
# 3             AĞRI               289454.0                   217813.0
# 4          AKSARAY               254480.0                   214971.0
# ..             ...                    ...                        ...
# 80            UŞAK               257681.0                   232030.0
# 81             VAN               600503.0                   486467.0
# 82          YALOVA               168185.0                   142074.0
# 83          YOZGAT               295666.0                   246930.0
# 84       ZONGULDAK               446210.0                   383793.0
#
#     İtirazsız Geçerli Oy Sayısı  İtirazlı Geçerli Oy Sayısı  \
# 0                     1255130.0                       599.0
# ...

# %%
df.il.nunique()
# Out:
# 85
